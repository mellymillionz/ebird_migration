# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nyc_bird_data_Mar_2020.txt', sep="\t")
# Out:
# /Users/melissamunz/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (9,10,21,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # **Initial Data Exploration:**

# %%
df.head()
# Out:
#                          GLOBAL UNIQUE IDENTIFIER     LAST EDITED DATE  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS786503632  2019-07-19 10:29:34
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS786499692  2019-07-19 10:15:03
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS786503672  2019-07-19 10:29:37
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS786503655  2019-07-19 10:29:35
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS786503665  2019-07-19 10:29:36
#
#    TAXONOMIC ORDER CATEGORY           COMMON NAME           SCIENTIFIC NAME  \
# 0            33194  species     Northern Cardinal     Cardinalis cardinalis
# 1             5892  species       Least Sandpiper        Calidris minutilla
# 2            23153  species          Barn Swallow           Hirundo rustica
# 3            26287  species         Carolina Wren  Thryothorus ludovicianus
# 4            32501  species  Red-winged Blackbird       Agelaius phoeniceus
#
#   SUBSPECIES COMMON NAME SUBSPECIES SCIENTIFIC NAME OBSERVATION COUNT  \
# 0                    NaN                        NaN                 X
# 1                    NaN                        NaN                 X
# 2                    NaN                        NaN                 X
# 3                    NaN                        NaN                 X
# 4                    NaN                        NaN                 X
#
#   BREEDING BIRD ATLAS CODE  ... NUMBER OBSERVERS ALL SPECIES REPORTED  \
# 0                      NaN  ...              NaN                    0
# 1                      NaN  ...              NaN                    0
# 2                      NaN  ...              NaN                    0
# 3                      NaN  ...              NaN                    0
# 4                      NaN  ...              NaN                    0
#
#   GROUP IDENTIFIER HAS MEDIA APPROVED REVIEWED REASON TRIP COMMENTS  \
# 0              NaN         0        1        0    NaN           NaN
# 1              NaN         0        1        0    NaN           NaN
# 2              NaN         0        1        0    NaN           NaN
# 3              NaN         0        1        0    NaN           NaN
# 4              NaN         0        1        0    NaN           NaN
#
#   SPECIES COMMENTS  Unnamed: 46
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
#
# [5 rows x 47 columns]

# %%
df.shape
# Out:
# (1699064, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699064 entries, 0 to 1699063
# Data columns (total 47 columns):
# GLOBAL UNIQUE IDENTIFIER        object
# LAST EDITED DATE                object
# TAXONOMIC ORDER                 int64
# CATEGORY                        object
# COMMON NAME                     object
# SCIENTIFIC NAME                 object
# SUBSPECIES COMMON NAME          object
# SUBSPECIES SCIENTIFIC NAME      object
# OBSERVATION COUNT               object
# BREEDING BIRD ATLAS CODE        object
# BREEDING BIRD ATLAS CATEGORY    object
# AGE/SEX                         object
# COUNTRY                         object
# COUNTRY CODE                    object
# STATE                           object
# STATE CODE                      object
# COUNTY                          object
# COUNTY CODE                     object
# IBA CODE                        object
# BCR CODE                        float64
# USFWS CODE                      float64
# ATLAS BLOCK                     object
# LOCALITY                        object
# LOCALITY ID                     object
# LOCALITY TYPE                   object
# LATITUDE                        float64
# LONGITUDE                       float64
# OBSERVATION DATE                object
# TIME OBSERVATIONS STARTED       object
# OBSERVER ID                     object
# SAMPLING EVENT IDENTIFIER       object
# PROTOCOL TYPE                   object
# PROTOCOL CODE                   object
# PROJECT CODE                    object
# DURATION MINUTES                float64
# EFFORT DISTANCE KM              float64
# EFFORT AREA HA                  float64
# NUMBER OBSERVERS                float64
# ALL SPECIES REPORTED            int64
# GROUP IDENTIFIER                object
# HAS MEDIA                       int64
# APPROVED                        int64
# REVIEWED                        int64
# REASON                          object
# TRIP COMMENTS                   object
# SPECIES COMMENTS                object
# Unnamed: 46                     float64
# dtypes: float64(9), int64(5), object(33)
# memory usage: 609.3+ MB

# %%
print(df.isna().sum())
# Out:
# GLOBAL UNIQUE IDENTIFIER              0
# LAST EDITED DATE                      0
# TAXONOMIC ORDER                       0
# CATEGORY                              0
# COMMON NAME                           0
# SCIENTIFIC NAME                       0
# SUBSPECIES COMMON NAME          1607383
# SUBSPECIES SCIENTIFIC NAME      1607383
# OBSERVATION COUNT                     0
# BREEDING BIRD ATLAS CODE        1674999
# BREEDING BIRD ATLAS CATEGORY    1674999
# AGE/SEX                         1646617
# COUNTRY                               0
# COUNTRY CODE                          0
# STATE                                 0
# STATE CODE                            0
# COUNTY                                0
# COUNTY CODE                           0
# IBA CODE                         444673
# BCR CODE                          96717
# USFWS CODE                      1699064
# ATLAS BLOCK                     1695513
# LOCALITY                              0
# LOCALITY ID                           0
# LOCALITY TYPE                         0
# LATITUDE                              0
# LONGITUDE                             0
# OBSERVATION DATE                      0
# TIME OBSERVATIONS STARTED         76232
# OBSERVER ID                           0
# SAMPLING EVENT IDENTIFIER             0
# PROTOCOL TYPE                         0
# PROTOCOL CODE                         0
# PROJECT CODE                          0
# DURATION MINUTES                 117453
# EFFORT DISTANCE KM               325799
# EFFORT AREA HA                  1655473
# NUMBER OBSERVERS                  41420
# ALL SPECIES REPORTED                  0
# GROUP IDENTIFIER                1483611
# HAS MEDIA                             0
# APPROVED                              0
# REVIEWED                              0
# REASON                          1698990
# TRIP COMMENTS                   1015914
# SPECIES COMMENTS                1464129
# Unnamed: 46                     1699064
# dtype: int64

# %% [markdown]
# # Convert to Datetime:

# %%
df['OBSERVATION DATE'].sample()
# Out:
# 1549071    2019-07-21
# Name: OBSERVATION DATE, dtype: object

# %%
df['OBSERVATION_DATE'] = pd.to_datetime(df['OBSERVATION DATE'])

# %%
df['MONTH'] = pd.DatetimeIndex(df['OBSERVATION_DATE']).month

# %%
df['MONTH'].unique()
# Out:
# array([10,  5,  4,  2, 12,  9, 11,  6,  3,  8,  7,  1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699064 entries, 0 to 1699063
# Data columns (total 49 columns):
# GLOBAL UNIQUE IDENTIFIER        object
# LAST EDITED DATE                object
# TAXONOMIC ORDER                 int64
# CATEGORY                        object
# COMMON NAME                     object
# SCIENTIFIC NAME                 object
# SUBSPECIES COMMON NAME          object
# SUBSPECIES SCIENTIFIC NAME      object
# OBSERVATION COUNT               object
# BREEDING BIRD ATLAS CODE        object
# BREEDING BIRD ATLAS CATEGORY    object
# AGE/SEX                         object
# COUNTRY                         object
# COUNTRY CODE                    object
# STATE                           object
# STATE CODE                      object
# COUNTY                          object
# COUNTY CODE                     object
# IBA CODE                        object
# BCR CODE                        float64
# USFWS CODE                      float64
# ATLAS BLOCK                     object
# LOCALITY                        object
# LOCALITY ID                     object
# LOCALITY TYPE                   object
# LATITUDE                        float64
# LONGITUDE                       float64
# OBSERVATION DATE                object
# TIME OBSERVATIONS STARTED       object
# OBSERVER ID                     object
# SAMPLING EVENT IDENTIFIER       object
# PROTOCOL TYPE                   object
# PROTOCOL CODE                   object
# PROJECT CODE                    object
# DURATION MINUTES                float64
# EFFORT DISTANCE KM              float64
# EFFORT AREA HA                  float64
# NUMBER OBSERVERS                float64
# ALL SPECIES REPORTED            int64
# GROUP IDENTIFIER                object
# HAS MEDIA                       int64
# APPROVED                        int64
# REVIEWED                        int64
# REASON                          object
# TRIP COMMENTS                   object
# SPECIES COMMENTS                object
# Unnamed: 46                     float64
# OBSERVATION_DATE                datetime64[ns]
# MONTH                           int64
# dtypes: datetime64[ns](1), float64(9), int64(6), object(33)
# memory usage: 635.2+ MB

# %%
#Every single entry in this dataset is marked APPROVED
df['APPROVED'].unique()
# Out:
# array([1])

# %% [markdown]
# # **Exploring Individual Features:**

# %% [markdown]
# **CATEGORY:** The category (e.g., species, hybrid, slash) assigned to this taxon in the eBird/Clements taxonomy.
#
# - Species: e.g., Tundra Swan
#
# - Hybrid: Hybrid between two species, e.g., Tundra x Trumpeter Swan (hybrid)
#
# - Intergrade: Hybrid between two subspecies or subspecies groups, e.g., Tundra Swan (Whistling x Bewick’s)
#
# - Spuh:  Genus or identification at broad level, e.g., swan sp.
#
# - Slash: Identification to Species-pair, e.g., Tundra/Trumpeter Swan
#
# - Domestic: Distinctly-plumaged domesticated varieties that may be free-flying (these do not count on personal lists) e.g., Mallard (Domestic type)
#
# - Form: Miscellaneous other taxa, including recently-described species yet to be accepted or distinctive forms that are not universally accepted, e.g., Red-tailed Hawk (abieticola), Upland Goose (Bar-breasted)

# %%
#Review all individual categories

print(df['CATEGORY'].unique())
# Out:
# ['species' 'form' 'domestic' 'slash' 'spuh' 'issf' 'hybrid']

# %%
category_groups = df.groupby(df['CATEGORY']).count()

# %%
category_groups
# Out:
#           GLOBAL UNIQUE IDENTIFIER  LAST EDITED DATE  TAXONOMIC ORDER  \
# CATEGORY
# domestic                     59483             59483            59483
# form                          2838              2838             2838
# hybrid                        1276              1276             1276
# issf                         29790             29790            29790
# slash                         1005              1005             1005
# species                    1587872           1587872          1587872
# spuh                         16800             16800            16800
#
#           COMMON NAME  SCIENTIFIC NAME  SUBSPECIES COMMON NAME  \
# CATEGORY
# domestic        59483            59483                   59053
# form             2838             2838                    2838
# hybrid           1276             1276                       0
# issf            29790            29790                   29790
# slash            1005             1005                       0
# species       1587872          1587872                       0
# spuh            16800            16800                       0
#
#           SUBSPECIES SCIENTIFIC NAME  OBSERVATION COUNT  \
# CATEGORY
# domestic                       59053              59483
# form                            2838               2838
# hybrid                             0               1276
# issf                           29790              29790
# slash                              0               1005
# species                            0            1587872
# spuh                               0              16800
#
#           BREEDING BIRD ATLAS CODE  BREEDING BIRD ATLAS CATEGORY  ...  \
# CATEGORY                                                          ...
# domestic                       460                           460  ...
# form                             4                             4  ...
# hybrid                           4                             4  ...
# issf                           475                           475  ...
# slash                            6                             6  ...
# species                      22537                         22537  ...
# spuh                           579                           579  ...
#
#           GROUP IDENTIFIER  HAS MEDIA  APPROVED  REVIEWED  REASON  \
# CATEGORY
# domestic              6558      59483     59483     59483       0
# form                   244       2838      2838      2838       0
# hybrid                 167       1276      1276      1276       0
# issf                  3905      29790     29790     29790       0
# slash                  146       1005      1005      1005       0
# species             202135    1587872   1587872   1587872      74
# spuh                  2298      16800     16800     16800       0
#
#           TRIP COMMENTS  SPECIES COMMENTS  Unnamed: 46  OBSERVATION_DATE  \
# CATEGORY
# domestic          23409              4908            0             59483
# form               1346               562            0              2838
# hybrid              641               195            0              1276
# issf              13367              3429            0             29790
# slash               390               456            0              1005
# species          636349            219655            0           1587872
# spuh               7648              5730            0             16800
#
#             MONTH
# CATEGORY
# domestic    59483
# form         2838
# hybrid       1276
# issf        29790
# slash        1005
# species   1587872
# spuh        16800
#
# [7 rows x 48 columns]

# %% [markdown]
# **COMMON NAME**:

# %%
#Review all species
total_species = len(df['COMMON NAME'].unique())
print(f'There are {total_species} total species')
# Out:
# There are 442 total species

# %%
df['COMMON NAME'].sample(30)
# Out:
# 1053420           Cape May Warbler
# 170533                Canada Goose
# 800574             Prairie Warbler
# 325588                     Mallard
# 796745            Northern Flicker
# 1385095              House Sparrow
# 883375                Canada Goose
# 1201721                House Finch
# 421032            Ring-billed Gull
# 990603             Northern Parula
# 886130            Hooded Merganser
# 127678                 Wood Thrush
# 396113      White-throated Sparrow
# 918628           Blackpoll Warbler
# 1272935               Herring Gull
# 1221791     Red-bellied Woodpecker
# 660302                Canada Goose
# 204108          American Goldfinch
# 1660261                    Mallard
# 444796           Northern Cardinal
# 73133            Northern Cardinal
# 808843              Warbling Vireo
# 1296378              Hermit Thrush
# 1093628    Great Black-backed Gull
# 280672                 House Finch
# 1272053               Gray Catbird
# 530956           European Starling
# 48248      Great Black-backed Gull
# 235360              Eastern Towhee
# 556407       Yellow-rumped Warbler
# Name: COMMON NAME, dtype: object

# %%
# Map sightings of a single species over time:

wt_sparrow = df[df['COMMON NAME'] == 'White-throated Sparrow']

wt_sparrow.head()
# Out:
#                            GLOBAL UNIQUE IDENTIFIER     LAST EDITED DATE  \
# 10   URN:CornellLabOfOrnithology:EBIRD:OBS786503626  2019-07-19 10:29:34
# 20   URN:CornellLabOfOrnithology:EBIRD:OBS786503629  2019-07-19 10:29:34
# 119  URN:CornellLabOfOrnithology:EBIRD:OBS521464350  2017-08-25 09:08:35
# 120  URN:CornellLabOfOrnithology:EBIRD:OBS523857555  2017-08-07 15:18:49
# 121  URN:CornellLabOfOrnithology:EBIRD:OBS523851879  2017-08-07 14:54:05
#
#      TAXONOMIC ORDER CATEGORY             COMMON NAME         SCIENTIFIC NAME  \
# 10             31943  species  White-throated Sparrow  Zonotrichia albicollis
# 20             31943  species  White-throated Sparrow  Zonotrichia albicollis
# 119            31943  species  White-throated Sparrow  Zonotrichia albicollis
# 120            31943  species  White-throated Sparrow  Zonotrichia albicollis
# 121            31943  species  White-throated Sparrow  Zonotrichia albicollis
#
#     SUBSPECIES COMMON NAME SUBSPECIES SCIENTIFIC NAME OBSERVATION COUNT  \
# 10                     NaN                        NaN                 X
# 20                     NaN                        NaN                 X
# 119                    NaN                        NaN                 1
# 120                    NaN                        NaN                 1
# 121                    NaN                        NaN                 2
#
#     BREEDING BIRD ATLAS CODE  ... GROUP IDENTIFIER HAS MEDIA APPROVED  \
# 10                       NaN  ...              NaN         0        1
# 20                       NaN  ...              NaN         0        1
# 119                      NaN  ...              NaN         0        1
# 120                      NaN  ...              NaN         0        1
# 121                      NaN  ...              NaN         0        1
#
#     REVIEWED REASON                                      TRIP COMMENTS  \
# 10         0    NaN                                                NaN
# 20         0    NaN                                                NaN
# 119        0    NaN  with  L. Griscom. Partly cloudy hazy and warm....
# 120        0    NaN  With Griscom-Met Mrs. Mead and Dr. Denton.  Co...
# 121        0    NaN  with Griscom and Cerosby. Wesather in the morn...
#
#     SPECIES COMMENTS Unnamed: 46 OBSERVATION_DATE  MONTH
# 10               NaN         NaN       1885-05-02      5
# 20               NaN         NaN       1888-05-03      5
# 119    heard singing         NaN       1925-04-22      4
# 120              NaN         NaN       1925-04-29      4
# 121  2 heard singing         NaN       1925-04-28      4
#
# [5 rows x 49 columns]

# %%
plt.figure(figsize=(12,8))
plt.bar(wt_sparrow['MONTH'], wt_sparrow['OBSERVATION COUNT'])
plt.ylabel('Total Observation Count')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# **OBSERVATION COUNT**:  The count of individuals made at the time of observation. If no count was made, an 'X' is used to indicate presence.

# %%
df['OBSERVATION COUNT'].sample(15)

# %% [markdown]
# # Final Dataframe for Analysis:

# %% [markdown]
# The final dataframe will contain:
#
# Original Columns:
# - GLOBAL UNIQUE IDENTIFIER
# - CATEGORY
# - COMMON NAME
#
# Created Columns:
# - OBSERVATION_DATE
# - MONTH

# %%
data = df['GLOBAL UNIQUE IDENTIFIER', 'CATEGORY', 'COMMON NAME', 'OBSERVATION COUNT', ]
